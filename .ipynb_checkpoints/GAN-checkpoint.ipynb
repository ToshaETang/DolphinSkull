# %%
# 保存生成器和判别器的權重
#generator.save_weights('generator_weights.h5')
#discriminator.save_weights('discriminator_weights.h5')

# %% [markdown]
# # 灰度轉換

# %%
# pip install opencv-python
# pip install opencv-python --upgrade

import cv2
import os

# 指定原始彩色圖像文件夾和目標灰度圖像文件夾
# original_folder = r'C:\Users\Tosha.E.T\Documents\GitHub\DolphinSkull\2022-3-8'
# gray_folder = r'C:\Users\Tosha.E.T\Documents\GitHub\DolphinSkull\2022-3-8\gray\class_1'
original_folder = r'C:\Users\Tosha.E.T\Documents\GitHub\DolphinSkull\number'
gray_folder = r'C:\Users\Tosha.E.T\Documents\GitHub\DolphinSkull\number\gray\class_1'

# 確保目標文件夾存在
if not os.path.exists(gray_folder):
    os.makedirs(gray_folder)

# 遍歷原始文件夾中的每個圖像
for filename in os.listdir(original_folder):
    if (filename.endswith('.JPG') or filename.endswith('.jpg')):
        # 讀取原始圖像
        original_image_path = os.path.join(original_folder, filename)
        original_image = cv2.imread(original_image_path)

        # 將彩色圖像轉換為灰度圖像
        gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

        # 保存灰度圖像到目標文件夾
        gray_image_path = os.path.join(gray_folder, filename)
        cv2.imwrite(gray_image_path, gray_image)

print("灰度轉換完成")
# Out:
# 灰度轉換完成

# %% [markdown]
# # 普通的GAN

# %%
import os
import numpy as np
import cv2 
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, PReLU
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import winsound

print("start")

plt.switch_backend('agg')

noise_dim = 100
w=25
h=25

class GAN(object):
    """ Generative Adversarial Network class """
    def __init__(self, width=w, height=h, channels=1):

        self.width = width
        self.height = height
        self.channels = channels

        self.shape = (self.width, self.height, self.channels)
        
        
        self.optimizer = Adam(learning_rate=0.0002, beta_1=0.6)
        self.optimizerG = Adam(learning_rate=0.0002, beta_1=0.6)
        self.optimizerD = Adam(learning_rate=0.0003, beta_1=0.6)
        '''
        self.optimizer = Adam(lr=0.0002, beta_1=0.6, decay=8e-8)
        self.optimizerG = Adam(lr=0.0002, beta_1=0.6, decay=8e-8)
        self.optimizerD = Adam(lr=0.0003, beta_1=0.6, decay=8e-8)
        '''

        self.G = self.__generator()
        self.G.compile(loss='binary_crossentropy', optimizer=self.optimizerG)

        self.D = self.__discriminator()
        self.D.compile(loss='binary_crossentropy', optimizer=self.optimizerD, metrics=['accuracy'])

        self.stacked_generator_discriminator = self.__stacked_generator_discriminator()

        self.stacked_generator_discriminator.compile(loss='binary_crossentropy', optimizer=self.optimizer)


    def __generator(self):
        """ Declare generator """

        model = Sequential()
        model.add(Dense(128, input_shape=(noise_dim,))) #noise_dim
        model.add(LeakyReLU(alpha=0.2)) #LeakyReLU(alpha=0.2)  #PReLU()
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(256))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(1024))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(self.width  * self.height * self.channels, activation='tanh'))
        model.add(Reshape((self.width, self.height, self.channels)))

        return model

    def __discriminator(self):
        """ Declare discriminator """

        model = Sequential()
        model.add(Flatten(input_shape=self.shape))
        model.add(Dense(1024))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(256))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(128))
        model.add(LeakyReLU(alpha=0.2))

        
        model.add(Dense(1, activation='sigmoid'))
        model.summary()

        return model

    def __stacked_generator_discriminator(self):

        self.D.trainable = False

        model = Sequential()
        model.add(self.G)
        model.add(self.D)

        return model
    
    
    def train(self, X_train, epochs=100000, batch=32, save_interval=100):
        for cnt in range(epochs+1):

            # train discriminator
            random_index = np.random.randint(0, len(X_train) - np.int64(batch/2))
            legit_images = X_train[random_index : random_index + np.int64(batch/2)]

            gen_noise = np.random.normal(0, 1, (np.int64(batch/2), noise_dim)) #noise_dim
            syntetic_images = self.G.predict(gen_noise)

            x_combined_batch = np.concatenate((legit_images, syntetic_images))
            y_combined_batch = np.concatenate((np.ones((np.int64(batch/2), 1)), np.zeros((np.int64(batch/2), 1))))

            d_loss = self.D.train_on_batch(x_combined_batch, y_combined_batch)

            # train generator
            noise = np.random.normal(0, 1, (batch, noise_dim)) #noise_dim
            y_mislabled = np.ones((batch, 1))
            g_loss = self.stacked_generator_discriminator.train_on_batch(noise, y_mislabled)

            print("epoch:", cnt, "[Discriminator :: d_loss: ", d_loss, "], [ Generator :: loss:", g_loss, "]")

            if cnt % save_interval == 0:
                self.plot_images(save2file=True, step=cnt)


    def plot_images(self, save2file=False, samples=16, step=0):
        if not os.path.exists("./images"):
            os.makedirs("./images")
        filename = "./images/dolphin_%d.png" % step
        noise = np.random.normal(0, 1, (samples, noise_dim)) #noise_dim

        images = self.G.predict(noise)

        plt.figure(figsize=(w, h))

        for i in range(images.shape[0]):
            plt.subplot(4, 4, i+1)
            image = images[i, :, :, 0]  # 取出灰階通道
            plt.imshow(image, cmap='gray')
            plt.axis('off')
        plt.tight_layout()

        if save2file:
            plt.savefig(filename)
            plt.close('all')
            winsound.Beep(1000,1000)
        else:
            plt.show()
    



if __name__ == '__main__':
    image_folder_path = r'2022-3-8\gray\class'
                        #r'C:\Users\Tosha.E.T\Documents\GitHub\DolphinSkull\number\gray\class_1'  
    image_files = os.listdir(image_folder_path)
    X_train = []

    for image_file in image_files:
        image_path = os.path.join(image_folder_path, image_file)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        if image is not None and not image.size == 0:
            # 如果圖片成功讀取，並且尺寸不為空，則進行調整大小
            image = cv2.resize(image, (w, h))
            X_train.append(image)
            #print(image)
        else:
            print(image_file)

    X_train = np.array(X_train) / 255.0
    X_train = np.expand_dims(X_train, axis=-1)

    gan = GAN()
    gan.train(X_train)
    

    
# 訓練完畢提示音    
winsound.Beep(2000,2000)
# Out:
# start
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)                  │ (None, 2500)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 1024)                │       2,561,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_20 (LeakyReLU)           │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_21 (LeakyReLU)           │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_22 (LeakyReLU)           │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_23 (LeakyReLU)           │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,250,177 (12.40 MB)
#  Trainable params: 3,250,177 (12.40 MB)
#  Non-trainable params: 0 (0.00 B)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# epoch: 0 [Discriminator :: d_loss:  [array(0.59082854, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.59082854, dtype=float32), array(0.59082854, dtype=float32), array(0.59082854, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch: 1 [Discriminator :: d_loss:  [array(0.60863125, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.60863125, dtype=float32), array(0.60863125, dtype=float32), array(0.60863125, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 2 [Discriminator :: d_loss:  [array(0.6188093, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.6188093, dtype=float32), array(0.6188093, dtype=float32), array(0.6188093, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 3 [Discriminator :: d_loss:  [array(0.6247629, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.6247629, dtype=float32), array(0.6247629, dtype=float32), array(0.6247629, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 4 [Discriminator :: d_loss:  [array(0.6361273, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.6361273, dtype=float32), array(0.6361273, dtype=float32), array(0.6361273, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 5 [Discriminator :: d_loss:  [array(0.6438512, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.6438512, dtype=float32), array(0.6438512, dtype=float32), array(0.6438512, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 6 [Discriminator :: d_loss:  [array(0.6605783, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.6605783, dtype=float32), array(0.6605783, dtype=float32), array(0.6605783, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 7 [Discriminator :: d_loss:  [array(0.6741073, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.6741073, dtype=float32), array(0.6741073, dtype=float32), array(0.6741073, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch: 8 [Discriminator :: d_loss:  [array(0.6904991, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.6904991, dtype=float32), array(0.6904991, dtype=float32), array(0.6904991, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 9 [Discriminator :: d_loss:  [array(0.7050387, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.7050387, dtype=float32), array(0.7050387, dtype=float32), array(0.7050387, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 10 [Discriminator :: d_loss:  [array(0.71930593, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.71930593, dtype=float32), array(0.71930593, dtype=float32), array(0.71930593, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 11 [Discriminator :: d_loss:  [array(0.7373591, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.7373591, dtype=float32), array(0.7373591, dtype=float32), array(0.7373591, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 12 [Discriminator :: d_loss:  [array(0.7578128, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.7578128, dtype=float32), array(0.7578128, dtype=float32), array(0.7578128, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch: 13 [Discriminator :: d_loss:  [array(0.7814561, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.7814561, dtype=float32), array(0.7814561, dtype=float32), array(0.7814561, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 14 [Discriminator :: d_loss:  [array(0.80153096, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.80153096, dtype=float32), array(0.80153096, dtype=float32), array(0.80153096, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 15 [Discriminator :: d_loss:  [array(0.82404685, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.82404685, dtype=float32), array(0.82404685, dtype=float32), array(0.82404685, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 16 [Discriminator :: d_loss:  [array(0.8468033, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.8468033, dtype=float32), array(0.8468033, dtype=float32), array(0.8468033, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 17 [Discriminator :: d_loss:  [array(0.86595273, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.86595273, dtype=float32), array(0.86595273, dtype=float32), array(0.86595273, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 18 [Discriminator :: d_loss:  [array(0.88749856, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.88749856, dtype=float32), array(0.88749856, dtype=float32), array(0.88749856, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 19 [Discriminator :: d_loss:  [array(0.9083511, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.9083511, dtype=float32), array(0.9083511, dtype=float32), array(0.9083511, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 20 [Discriminator :: d_loss:  [array(0.9278981, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.9278981, dtype=float32), array(0.9278981, dtype=float32), array(0.9278981, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 21 [Discriminator :: d_loss:  [array(0.9493063, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.9493063, dtype=float32), array(0.9493063, dtype=float32), array(0.9493063, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 22 [Discriminator :: d_loss:  [array(0.96906745, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.96906745, dtype=float32), array(0.96906745, dtype=float32), array(0.96906745, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch: 23 [Discriminator :: d_loss:  [array(0.9933544, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(0.9933544, dtype=float32), array(0.9933544, dtype=float32), array(0.9933544, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 24 [Discriminator :: d_loss:  [array(1.0130006, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.0130006, dtype=float32), array(1.0130006, dtype=float32), array(1.0130006, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 25 [Discriminator :: d_loss:  [array(1.037082, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.037082, dtype=float32), array(1.037082, dtype=float32), array(1.037082, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 26 [Discriminator :: d_loss:  [array(1.0613477, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.0613477, dtype=float32), array(1.0613477, dtype=float32), array(1.0613477, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch: 27 [Discriminator :: d_loss:  [array(1.0827395, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.0827395, dtype=float32), array(1.0827395, dtype=float32), array(1.0827395, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 28 [Discriminator :: d_loss:  [array(1.100985, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.100985, dtype=float32), array(1.100985, dtype=float32), array(1.100985, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 29 [Discriminator :: d_loss:  [array(1.1216778, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.1216778, dtype=float32), array(1.1216778, dtype=float32), array(1.1216778, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 30 [Discriminator :: d_loss:  [array(1.1423862, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.1423862, dtype=float32), array(1.1423862, dtype=float32), array(1.1423862, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch: 31 [Discriminator :: d_loss:  [array(1.1596881, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.1596881, dtype=float32), array(1.1596881, dtype=float32), array(1.1596881, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# epoch: 32 [Discriminator :: d_loss:  [array(1.1755872, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.1755872, dtype=float32), array(1.1755872, dtype=float32), array(1.1755872, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# epoch: 33 [Discriminator :: d_loss:  [array(1.1940508, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.1940508, dtype=float32), array(1.1940508, dtype=float32), array(1.1940508, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 34 [Discriminator :: d_loss:  [array(1.2116351, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.2116351, dtype=float32), array(1.2116351, dtype=float32), array(1.2116351, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch: 35 [Discriminator :: d_loss:  [array(1.2265787, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.2265787, dtype=float32), array(1.2265787, dtype=float32), array(1.2265787, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 36 [Discriminator :: d_loss:  [array(1.2415737, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.2415737, dtype=float32), array(1.2415737, dtype=float32), array(1.2415737, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# epoch: 37 [Discriminator :: d_loss:  [array(1.2600162, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.2600162, dtype=float32), array(1.2600162, dtype=float32), array(1.2600162, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 38 [Discriminator :: d_loss:  [array(1.2807713, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.2807713, dtype=float32), array(1.2807713, dtype=float32), array(1.2807713, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 39 [Discriminator :: d_loss:  [array(1.2964022, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.2964022, dtype=float32), array(1.2964022, dtype=float32), array(1.2964022, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 40 [Discriminator :: d_loss:  [array(1.3108473, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.3108473, dtype=float32), array(1.3108473, dtype=float32), array(1.3108473, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# epoch: 41 [Discriminator :: d_loss:  [array(1.3284497, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.3284497, dtype=float32), array(1.3284497, dtype=float32), array(1.3284497, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 42 [Discriminator :: d_loss:  [array(1.3467702, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.3467702, dtype=float32), array(1.3467702, dtype=float32), array(1.3467702, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# epoch: 43 [Discriminator :: d_loss:  [array(1.3663142, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.3663142, dtype=float32), array(1.3663142, dtype=float32), array(1.3663142, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# epoch: 44 [Discriminator :: d_loss:  [array(1.3857311, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.3857311, dtype=float32), array(1.3857311, dtype=float32), array(1.3857311, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 45 [Discriminator :: d_loss:  [array(1.4006822, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.4006822, dtype=float32), array(1.4006822, dtype=float32), array(1.4006822, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 46 [Discriminator :: d_loss:  [array(1.4179493, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.4179493, dtype=float32), array(1.4179493, dtype=float32), array(1.4179493, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 47 [Discriminator :: d_loss:  [array(1.4336969, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.4336969, dtype=float32), array(1.4336969, dtype=float32), array(1.4336969, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 48 [Discriminator :: d_loss:  [array(1.449776, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.449776, dtype=float32), array(1.449776, dtype=float32), array(1.449776, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 49 [Discriminator :: d_loss:  [array(1.461388, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.461388, dtype=float32), array(1.461388, dtype=float32), array(1.461388, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 50 [Discriminator :: d_loss:  [array(1.4774408, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.4774408, dtype=float32), array(1.4774408, dtype=float32), array(1.4774408, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 51 [Discriminator :: d_loss:  [array(1.4899042, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.4899042, dtype=float32), array(1.4899042, dtype=float32), array(1.4899042, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 52 [Discriminator :: d_loss:  [array(1.5013524, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.5013524, dtype=float32), array(1.5013524, dtype=float32), array(1.5013524, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 53 [Discriminator :: d_loss:  [array(1.5128754, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.5128754, dtype=float32), array(1.5128754, dtype=float32), array(1.5128754, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 54 [Discriminator :: d_loss:  [array(1.5260593, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.5260593, dtype=float32), array(1.5260593, dtype=float32), array(1.5260593, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 55 [Discriminator :: d_loss:  [array(1.538619, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.538619, dtype=float32), array(1.538619, dtype=float32), array(1.538619, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 56 [Discriminator :: d_loss:  [array(1.5522686, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.5522686, dtype=float32), array(1.5522686, dtype=float32), array(1.5522686, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 57 [Discriminator :: d_loss:  [array(1.5645452, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.5645452, dtype=float32), array(1.5645452, dtype=float32), array(1.5645452, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 58 [Discriminator :: d_loss:  [array(1.5751872, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.5751872, dtype=float32), array(1.5751872, dtype=float32), array(1.5751872, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 59 [Discriminator :: d_loss:  [array(1.5857899, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.5857899, dtype=float32), array(1.5857899, dtype=float32), array(1.5857899, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 60 [Discriminator :: d_loss:  [array(1.6004068, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6004068, dtype=float32), array(1.6004068, dtype=float32), array(1.6004068, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 61 [Discriminator :: d_loss:  [array(1.6169639, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6169639, dtype=float32), array(1.6169639, dtype=float32), array(1.6169639, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 62 [Discriminator :: d_loss:  [array(1.6299427, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6299427, dtype=float32), array(1.6299427, dtype=float32), array(1.6299427, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 63 [Discriminator :: d_loss:  [array(1.6424422, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6424422, dtype=float32), array(1.6424422, dtype=float32), array(1.6424422, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 64 [Discriminator :: d_loss:  [array(1.6533487, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6533487, dtype=float32), array(1.6533487, dtype=float32), array(1.6533487, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 65 [Discriminator :: d_loss:  [array(1.6637422, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6637422, dtype=float32), array(1.6637422, dtype=float32), array(1.6637422, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch: 66 [Discriminator :: d_loss:  [array(1.6738175, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6738175, dtype=float32), array(1.6738175, dtype=float32), array(1.6738175, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 67 [Discriminator :: d_loss:  [array(1.6837989, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6837989, dtype=float32), array(1.6837989, dtype=float32), array(1.6837989, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 68 [Discriminator :: d_loss:  [array(1.6906672, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6906672, dtype=float32), array(1.6906672, dtype=float32), array(1.6906672, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 69 [Discriminator :: d_loss:  [array(1.6996541, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.6996541, dtype=float32), array(1.6996541, dtype=float32), array(1.6996541, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 70 [Discriminator :: d_loss:  [array(1.7128314, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.7128314, dtype=float32), array(1.7128314, dtype=float32), array(1.7128314, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 71 [Discriminator :: d_loss:  [array(1.7248175, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.7248175, dtype=float32), array(1.7248175, dtype=float32), array(1.7248175, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 72 [Discriminator :: d_loss:  [array(1.7354954, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.7354954, dtype=float32), array(1.7354954, dtype=float32), array(1.7354954, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 73 [Discriminator :: d_loss:  [array(1.7461598, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.7461598, dtype=float32), array(1.7461598, dtype=float32), array(1.7461598, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 74 [Discriminator :: d_loss:  [array(1.7545359, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.7545359, dtype=float32), array(1.7545359, dtype=float32), array(1.7545359, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 75 [Discriminator :: d_loss:  [array(1.7657818, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.7657818, dtype=float32), array(1.7657818, dtype=float32), array(1.7657818, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 76 [Discriminator :: d_loss:  [array(1.7780687, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.7780687, dtype=float32), array(1.7780687, dtype=float32), array(1.7780687, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 77 [Discriminator :: d_loss:  [array(1.7894694, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.7894694, dtype=float32), array(1.7894694, dtype=float32), array(1.7894694, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 78 [Discriminator :: d_loss:  [array(1.797288, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.797288, dtype=float32), array(1.797288, dtype=float32), array(1.797288, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 79 [Discriminator :: d_loss:  [array(1.8087921, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8087921, dtype=float32), array(1.8087921, dtype=float32), array(1.8087921, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 80 [Discriminator :: d_loss:  [array(1.8187919, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8187919, dtype=float32), array(1.8187919, dtype=float32), array(1.8187919, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 81 [Discriminator :: d_loss:  [array(1.8295633, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8295633, dtype=float32), array(1.8295633, dtype=float32), array(1.8295633, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 82 [Discriminator :: d_loss:  [array(1.8398848, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8398848, dtype=float32), array(1.8398848, dtype=float32), array(1.8398848, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 83 [Discriminator :: d_loss:  [array(1.8479698, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8479698, dtype=float32), array(1.8479698, dtype=float32), array(1.8479698, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# epoch: 84 [Discriminator :: d_loss:  [array(1.8579108, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8579108, dtype=float32), array(1.8579108, dtype=float32), array(1.8579108, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 85 [Discriminator :: d_loss:  [array(1.8683702, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8683702, dtype=float32), array(1.8683702, dtype=float32), array(1.8683702, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 86 [Discriminator :: d_loss:  [array(1.8776755, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8776755, dtype=float32), array(1.8776755, dtype=float32), array(1.8776755, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 87 [Discriminator :: d_loss:  [array(1.8861785, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8861785, dtype=float32), array(1.8861785, dtype=float32), array(1.8861785, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch: 88 [Discriminator :: d_loss:  [array(1.8935612, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.8935612, dtype=float32), array(1.8935612, dtype=float32), array(1.8935612, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 89 [Discriminator :: d_loss:  [array(1.9017658, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.9017658, dtype=float32), array(1.9017658, dtype=float32), array(1.9017658, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 90 [Discriminator :: d_loss:  [array(1.9097248, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.9097248, dtype=float32), array(1.9097248, dtype=float32), array(1.9097248, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 91 [Discriminator :: d_loss:  [array(1.9178251, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.9178251, dtype=float32), array(1.9178251, dtype=float32), array(1.9178251, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 92 [Discriminator :: d_loss:  [array(1.9279633, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.9279633, dtype=float32), array(1.9279633, dtype=float32), array(1.9279633, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 93 [Discriminator :: d_loss:  [array(1.9373964, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.9373964, dtype=float32), array(1.9373964, dtype=float32), array(1.9373964, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# epoch: 94 [Discriminator :: d_loss:  [array(1.946509, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.946509, dtype=float32), array(1.946509, dtype=float32), array(1.946509, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 95 [Discriminator :: d_loss:  [array(1.9565187, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.9565187, dtype=float32), array(1.9565187, dtype=float32), array(1.9565187, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 96 [Discriminator :: d_loss:  [array(1.964646, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.964646, dtype=float32), array(1.964646, dtype=float32), array(1.964646, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 97 [Discriminator :: d_loss:  [array(1.9757297, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.9757297, dtype=float32), array(1.9757297, dtype=float32), array(1.9757297, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 98 [Discriminator :: d_loss:  [array(1.9868207, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.9868207, dtype=float32), array(1.9868207, dtype=float32), array(1.9868207, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# epoch: 99 [Discriminator :: d_loss:  [array(1.9936013, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(1.9936013, dtype=float32), array(1.9936013, dtype=float32), array(1.9936013, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# epoch: 100 [Discriminator :: d_loss:  [array(2.0012255, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0012255, dtype=float32), array(2.0012255, dtype=float32), array(2.0012255, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 101 [Discriminator :: d_loss:  [array(2.0104392, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0104392, dtype=float32), array(2.0104392, dtype=float32), array(2.0104392, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 102 [Discriminator :: d_loss:  [array(2.0166714, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0166714, dtype=float32), array(2.0166714, dtype=float32), array(2.0166714, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 103 [Discriminator :: d_loss:  [array(2.026117, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.026117, dtype=float32), array(2.026117, dtype=float32), array(2.026117, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 104 [Discriminator :: d_loss:  [array(2.0360756, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0360756, dtype=float32), array(2.0360756, dtype=float32), array(2.0360756, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 105 [Discriminator :: d_loss:  [array(2.0432818, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0432818, dtype=float32), array(2.0432818, dtype=float32), array(2.0432818, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 106 [Discriminator :: d_loss:  [array(2.0518076, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0518076, dtype=float32), array(2.0518076, dtype=float32), array(2.0518076, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 107 [Discriminator :: d_loss:  [array(2.0594552, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0594552, dtype=float32), array(2.0594552, dtype=float32), array(2.0594552, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 108 [Discriminator :: d_loss:  [array(2.0658033, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0658033, dtype=float32), array(2.0658033, dtype=float32), array(2.0658033, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# epoch: 109 [Discriminator :: d_loss:  [array(2.0745838, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0745838, dtype=float32), array(2.0745838, dtype=float32), array(2.0745838, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 110 [Discriminator :: d_loss:  [array(2.0831885, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0831885, dtype=float32), array(2.0831885, dtype=float32), array(2.0831885, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch: 111 [Discriminator :: d_loss:  [array(2.0940804, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.0940804, dtype=float32), array(2.0940804, dtype=float32), array(2.0940804, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 112 [Discriminator :: d_loss:  [array(2.1021094, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1021094, dtype=float32), array(2.1021094, dtype=float32), array(2.1021094, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# epoch: 113 [Discriminator :: d_loss:  [array(2.109755, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.109755, dtype=float32), array(2.109755, dtype=float32), array(2.109755, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch: 114 [Discriminator :: d_loss:  [array(2.1164749, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1164749, dtype=float32), array(2.1164749, dtype=float32), array(2.1164749, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# epoch: 115 [Discriminator :: d_loss:  [array(2.1219637, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1219637, dtype=float32), array(2.1219637, dtype=float32), array(2.1219637, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# epoch: 116 [Discriminator :: d_loss:  [array(2.1285753, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1285753, dtype=float32), array(2.1285753, dtype=float32), array(2.1285753, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 117 [Discriminator :: d_loss:  [array(2.136411, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.136411, dtype=float32), array(2.136411, dtype=float32), array(2.136411, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 118 [Discriminator :: d_loss:  [array(2.1444192, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1444192, dtype=float32), array(2.1444192, dtype=float32), array(2.1444192, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch: 119 [Discriminator :: d_loss:  [array(2.1505742, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1505742, dtype=float32), array(2.1505742, dtype=float32), array(2.1505742, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# epoch: 120 [Discriminator :: d_loss:  [array(2.1568968, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1568968, dtype=float32), array(2.1568968, dtype=float32), array(2.1568968, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# epoch: 121 [Discriminator :: d_loss:  [array(2.1651137, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1651137, dtype=float32), array(2.1651137, dtype=float32), array(2.1651137, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 122 [Discriminator :: d_loss:  [array(2.1702318, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1702318, dtype=float32), array(2.1702318, dtype=float32), array(2.1702318, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 123 [Discriminator :: d_loss:  [array(2.1773937, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1773937, dtype=float32), array(2.1773937, dtype=float32), array(2.1773937, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 124 [Discriminator :: d_loss:  [array(2.1845999, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1845999, dtype=float32), array(2.1845999, dtype=float32), array(2.1845999, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 125 [Discriminator :: d_loss:  [array(2.1911674, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1911674, dtype=float32), array(2.1911674, dtype=float32), array(2.1911674, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 126 [Discriminator :: d_loss:  [array(2.1972344, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.1972344, dtype=float32), array(2.1972344, dtype=float32), array(2.1972344, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch: 127 [Discriminator :: d_loss:  [array(2.20384, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.20384, dtype=float32), array(2.20384, dtype=float32), array(2.20384, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# epoch: 128 [Discriminator :: d_loss:  [array(2.2104244, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2104244, dtype=float32), array(2.2104244, dtype=float32), array(2.2104244, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# epoch: 129 [Discriminator :: d_loss:  [array(2.2178266, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2178266, dtype=float32), array(2.2178266, dtype=float32), array(2.2178266, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 130 [Discriminator :: d_loss:  [array(2.2245135, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2245135, dtype=float32), array(2.2245135, dtype=float32), array(2.2245135, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 131 [Discriminator :: d_loss:  [array(2.2294724, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2294724, dtype=float32), array(2.2294724, dtype=float32), array(2.2294724, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 132 [Discriminator :: d_loss:  [array(2.2358935, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2358935, dtype=float32), array(2.2358935, dtype=float32), array(2.2358935, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 133 [Discriminator :: d_loss:  [array(2.2413206, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2413206, dtype=float32), array(2.2413206, dtype=float32), array(2.2413206, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 134 [Discriminator :: d_loss:  [array(2.2480116, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2480116, dtype=float32), array(2.2480116, dtype=float32), array(2.2480116, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 135 [Discriminator :: d_loss:  [array(2.2539754, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2539754, dtype=float32), array(2.2539754, dtype=float32), array(2.2539754, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 136 [Discriminator :: d_loss:  [array(2.2605872, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2605872, dtype=float32), array(2.2605872, dtype=float32), array(2.2605872, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 137 [Discriminator :: d_loss:  [array(2.2681081, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2681081, dtype=float32), array(2.2681081, dtype=float32), array(2.2681081, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 138 [Discriminator :: d_loss:  [array(2.2734907, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2734907, dtype=float32), array(2.2734907, dtype=float32), array(2.2734907, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 139 [Discriminator :: d_loss:  [array(2.2801423, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2801423, dtype=float32), array(2.2801423, dtype=float32), array(2.2801423, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 140 [Discriminator :: d_loss:  [array(2.285348, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.285348, dtype=float32), array(2.285348, dtype=float32), array(2.285348, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch: 141 [Discriminator :: d_loss:  [array(2.2911775, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.2911775, dtype=float32), array(2.2911775, dtype=float32), array(2.2911775, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 142 [Discriminator :: d_loss:  [array(2.297322, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.297322, dtype=float32), array(2.297322, dtype=float32), array(2.297322, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 143 [Discriminator :: d_loss:  [array(2.3034554, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3034554, dtype=float32), array(2.3034554, dtype=float32), array(2.3034554, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch: 144 [Discriminator :: d_loss:  [array(2.309496, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.309496, dtype=float32), array(2.309496, dtype=float32), array(2.309496, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 145 [Discriminator :: d_loss:  [array(2.3168547, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3168547, dtype=float32), array(2.3168547, dtype=float32), array(2.3168547, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 146 [Discriminator :: d_loss:  [array(2.3228576, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3228576, dtype=float32), array(2.3228576, dtype=float32), array(2.3228576, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 147 [Discriminator :: d_loss:  [array(2.3294833, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3294833, dtype=float32), array(2.3294833, dtype=float32), array(2.3294833, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 148 [Discriminator :: d_loss:  [array(2.3354895, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3354895, dtype=float32), array(2.3354895, dtype=float32), array(2.3354895, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 149 [Discriminator :: d_loss:  [array(2.341165, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.341165, dtype=float32), array(2.341165, dtype=float32), array(2.341165, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 150 [Discriminator :: d_loss:  [array(2.3464148, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3464148, dtype=float32), array(2.3464148, dtype=float32), array(2.3464148, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 151 [Discriminator :: d_loss:  [array(2.3507013, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3507013, dtype=float32), array(2.3507013, dtype=float32), array(2.3507013, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch: 152 [Discriminator :: d_loss:  [array(2.3573196, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3573196, dtype=float32), array(2.3573196, dtype=float32), array(2.3573196, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 153 [Discriminator :: d_loss:  [array(2.3633165, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3633165, dtype=float32), array(2.3633165, dtype=float32), array(2.3633165, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 154 [Discriminator :: d_loss:  [array(2.3693752, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3693752, dtype=float32), array(2.3693752, dtype=float32), array(2.3693752, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 155 [Discriminator :: d_loss:  [array(2.3748398, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3748398, dtype=float32), array(2.3748398, dtype=float32), array(2.3748398, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch: 156 [Discriminator :: d_loss:  [array(2.3814797, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.3814797, dtype=float32), array(2.3814797, dtype=float32), array(2.3814797, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch: 157 [Discriminator :: d_loss:  [array(2.385987, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(2.385987, dtype=float32), array(2.385987, dtype=float32), array(2.385987, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 593 [Discriminator :: d_loss:  [array(3.5057604, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5057604, dtype=float32), array(3.5057604, dtype=float32), array(3.5057604, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 594 [Discriminator :: d_loss:  [array(3.5074756, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5074756, dtype=float32), array(3.5074756, dtype=float32), array(3.5074756, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 595 [Discriminator :: d_loss:  [array(3.509039, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.509039, dtype=float32), array(3.509039, dtype=float32), array(3.509039, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 596 [Discriminator :: d_loss:  [array(3.510354, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.510354, dtype=float32), array(3.510354, dtype=float32), array(3.510354, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 597 [Discriminator :: d_loss:  [array(3.5115464, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5115464, dtype=float32), array(3.5115464, dtype=float32), array(3.5115464, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 598 [Discriminator :: d_loss:  [array(3.5131898, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5131898, dtype=float32), array(3.5131898, dtype=float32), array(3.5131898, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 599 [Discriminator :: d_loss:  [array(3.514222, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.514222, dtype=float32), array(3.514222, dtype=float32), array(3.514222, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 600 [Discriminator :: d_loss:  [array(3.5155385, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5155385, dtype=float32), array(3.5155385, dtype=float32), array(3.5155385, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch: 601 [Discriminator :: d_loss:  [array(3.5170186, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5170186, dtype=float32), array(3.5170186, dtype=float32), array(3.5170186, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 602 [Discriminator :: d_loss:  [array(3.5180805, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5180805, dtype=float32), array(3.5180805, dtype=float32), array(3.5180805, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 603 [Discriminator :: d_loss:  [array(3.5191417, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5191417, dtype=float32), array(3.5191417, dtype=float32), array(3.5191417, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 604 [Discriminator :: d_loss:  [array(3.5206447, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5206447, dtype=float32), array(3.5206447, dtype=float32), array(3.5206447, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 605 [Discriminator :: d_loss:  [array(3.5219388, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5219388, dtype=float32), array(3.5219388, dtype=float32), array(3.5219388, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 606 [Discriminator :: d_loss:  [array(3.52338, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.52338, dtype=float32), array(3.52338, dtype=float32), array(3.52338, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 607 [Discriminator :: d_loss:  [array(3.5249605, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5249605, dtype=float32), array(3.5249605, dtype=float32), array(3.5249605, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 608 [Discriminator :: d_loss:  [array(3.525943, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.525943, dtype=float32), array(3.525943, dtype=float32), array(3.525943, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 609 [Discriminator :: d_loss:  [array(3.5272193, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5272193, dtype=float32), array(3.5272193, dtype=float32), array(3.5272193, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 610 [Discriminator :: d_loss:  [array(3.5281162, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5281162, dtype=float32), array(3.5281162, dtype=float32), array(3.5281162, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 611 [Discriminator :: d_loss:  [array(3.529355, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.529355, dtype=float32), array(3.529355, dtype=float32), array(3.529355, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch: 612 [Discriminator :: d_loss:  [array(3.5304809, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5304809, dtype=float32), array(3.5304809, dtype=float32), array(3.5304809, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 613 [Discriminator :: d_loss:  [array(3.5317223, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5317223, dtype=float32), array(3.5317223, dtype=float32), array(3.5317223, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 614 [Discriminator :: d_loss:  [array(3.5330784, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5330784, dtype=float32), array(3.5330784, dtype=float32), array(3.5330784, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 615 [Discriminator :: d_loss:  [array(3.5345747, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5345747, dtype=float32), array(3.5345747, dtype=float32), array(3.5345747, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 616 [Discriminator :: d_loss:  [array(3.535872, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.535872, dtype=float32), array(3.535872, dtype=float32), array(3.535872, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 617 [Discriminator :: d_loss:  [array(3.537119, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.537119, dtype=float32), array(3.537119, dtype=float32), array(3.537119, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 618 [Discriminator :: d_loss:  [array(3.538188, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.538188, dtype=float32), array(3.538188, dtype=float32), array(3.538188, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# epoch: 619 [Discriminator :: d_loss:  [array(3.5396893, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5396893, dtype=float32), array(3.5396893, dtype=float32), array(3.5396893, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 620 [Discriminator :: d_loss:  [array(3.5410192, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5410192, dtype=float32), array(3.5410192, dtype=float32), array(3.5410192, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 621 [Discriminator :: d_loss:  [array(3.5421126, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5421126, dtype=float32), array(3.5421126, dtype=float32), array(3.5421126, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# epoch: 622 [Discriminator :: d_loss:  [array(3.5434566, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5434566, dtype=float32), array(3.5434566, dtype=float32), array(3.5434566, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# epoch: 623 [Discriminator :: d_loss:  [array(3.5444794, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5444794, dtype=float32), array(3.5444794, dtype=float32), array(3.5444794, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch: 624 [Discriminator :: d_loss:  [array(3.546075, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.546075, dtype=float32), array(3.546075, dtype=float32), array(3.546075, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch: 625 [Discriminator :: d_loss:  [array(3.5473013, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5473013, dtype=float32), array(3.5473013, dtype=float32), array(3.5473013, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 626 [Discriminator :: d_loss:  [array(3.5486615, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5486615, dtype=float32), array(3.5486615, dtype=float32), array(3.5486615, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# epoch: 627 [Discriminator :: d_loss:  [array(3.550322, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.550322, dtype=float32), array(3.550322, dtype=float32), array(3.550322, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 628 [Discriminator :: d_loss:  [array(3.5519996, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5519996, dtype=float32), array(3.5519996, dtype=float32), array(3.5519996, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 629 [Discriminator :: d_loss:  [array(3.5533276, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5533276, dtype=float32), array(3.5533276, dtype=float32), array(3.5533276, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 630 [Discriminator :: d_loss:  [array(3.554802, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.554802, dtype=float32), array(3.554802, dtype=float32), array(3.554802, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 631 [Discriminator :: d_loss:  [array(3.555654, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.555654, dtype=float32), array(3.555654, dtype=float32), array(3.555654, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# epoch: 632 [Discriminator :: d_loss:  [array(3.5571363, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5571363, dtype=float32), array(3.5571363, dtype=float32), array(3.5571363, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# epoch: 633 [Discriminator :: d_loss:  [array(3.5585186, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5585186, dtype=float32), array(3.5585186, dtype=float32), array(3.5585186, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 634 [Discriminator :: d_loss:  [array(3.5599432, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5599432, dtype=float32), array(3.5599432, dtype=float32), array(3.5599432, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 635 [Discriminator :: d_loss:  [array(3.5610428, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5610428, dtype=float32), array(3.5610428, dtype=float32), array(3.5610428, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 636 [Discriminator :: d_loss:  [array(3.5623941, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5623941, dtype=float32), array(3.5623941, dtype=float32), array(3.5623941, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# epoch: 637 [Discriminator :: d_loss:  [array(3.5637465, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5637465, dtype=float32), array(3.5637465, dtype=float32), array(3.5637465, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# epoch: 638 [Discriminator :: d_loss:  [array(3.564679, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.564679, dtype=float32), array(3.564679, dtype=float32), array(3.564679, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 639 [Discriminator :: d_loss:  [array(3.5658703, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5658703, dtype=float32), array(3.5658703, dtype=float32), array(3.5658703, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 640 [Discriminator :: d_loss:  [array(3.5674293, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5674293, dtype=float32), array(3.5674293, dtype=float32), array(3.5674293, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 641 [Discriminator :: d_loss:  [array(3.5684118, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5684118, dtype=float32), array(3.5684118, dtype=float32), array(3.5684118, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 642 [Discriminator :: d_loss:  [array(3.5699224, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5699224, dtype=float32), array(3.5699224, dtype=float32), array(3.5699224, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# epoch: 643 [Discriminator :: d_loss:  [array(3.5714805, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5714805, dtype=float32), array(3.5714805, dtype=float32), array(3.5714805, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# epoch: 644 [Discriminator :: d_loss:  [array(3.572871, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.572871, dtype=float32), array(3.572871, dtype=float32), array(3.572871, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch: 645 [Discriminator :: d_loss:  [array(3.5740082, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5740082, dtype=float32), array(3.5740082, dtype=float32), array(3.5740082, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch: 646 [Discriminator :: d_loss:  [array(3.5750213, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.5750213, dtype=float32), array(3.5750213, dtype=float32), array(3.5750213, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# epoch: 647 [Discriminator :: d_loss:  [array(3.576199, dtype=float32), array(0.5, dtype=float32)] ], [ Generator :: loss: [array(3.576199, dtype=float32), array(3.576199, dtype=float32), array(3.576199, dtype=float32), array(0.5, dtype=float32)] ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
https://www.tensorflow.org/tutorials/quickstart/beginner

# %%
pip list
# Out:
# Package                   VersionNote: you may need to restart the kernel to use updated packages.
#
# ------------------------- --------------
# absl-py                   2.1.0
# anyio                     4.3.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# astunparse                1.6.3
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.15.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# certifi                   2024.2.2
# cffi                      1.16.0
# charset-normalizer        3.3.2
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.2.1
# cycler                    0.12.1
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.0.1
# fastjsonschema            2.19.1
# flatbuffers               24.3.25
# fonttools                 4.51.0
# fqdn                      1.5.1
# gast                      0.5.4
# google-pasta              0.2.0
# grpcio                    1.64.0
# h11                       0.14.0
# h5py                      3.11.0
# httpcore                  1.0.5
# httpx                     0.27.0
# idna                      3.7
# ipykernel                 6.29.4
# ipython                   8.24.0
# ipywidgets                8.1.2
# isoduration               20.11.0
# jedi                      0.19.1
# Jinja2                    3.1.4
# json5                     0.9.25
# jsonpointer               2.4
# jsonschema                4.22.0
# jsonschema-specifications 2023.12.1
# jupyter                   1.0.0
# jupyter_client            8.6.1
# jupyter-console           6.6.3
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.2.1
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.2
# jupyterlab_widgets        3.0.10
# keras                     3.3.3
# kiwisolver                1.4.5
# libclang                  18.1.1
# Markdown                  3.6
# markdown-it-py            3.0.0
# MarkupSafe                2.1.5
# matplotlib                3.9.0
# matplotlib-inline         0.1.7
# mdurl                     0.1.2
# mistune                   3.0.2
# ml-dtypes                 0.3.2
# namex                     0.0.8
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.2.0
# notebook_shim             0.2.4
# numpy                     1.26.4
# opencv-python             4.9.0.80
# opt-einsum                3.3.0
# optree                    0.11.0
# overrides                 7.7.0
# packaging                 24.0
# pandocfilters             1.5.1
# parso                     0.8.4
# pillow                    10.3.0
# pip                       24.0
# platformdirs              4.2.2
# prometheus_client         0.20.0
# prompt-toolkit            3.0.43
# protobuf                  4.25.3
# psutil                    5.9.8
# pure-eval                 0.2.2
# pycparser                 2.22
# Pygments                  2.18.0
# pyparsing                 3.1.2
# python-dateutil           2.9.0.post0
# python-json-logger        2.0.7
# pywin32                   306
# pywinpty                  2.0.13
# PyYAML                    6.0.1
# pyzmq                     26.0.3
# qtconsole                 5.5.2
# QtPy                      2.4.1
# referencing               0.35.1
# requests                  2.32.2
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rich                      13.7.1
# rpds-py                   0.18.1
# Send2Trash                1.8.3
# setuptools                70.0.0
# six                       1.16.0
# sniffio                   1.3.1
# soupsieve                 2.5
# stack-data                0.6.3
# tensorboard               2.16.2
# tensorboard-data-server   0.7.2
# tensorflow                2.16.1
# tensorflow-intel          2.16.1
# termcolor                 2.4.0
# terminado                 0.18.1
# tinycss2                  1.3.0
# tornado                   6.4
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20240316
# typing_extensions         4.12.0
# uri-template              1.3.0
# urllib3                   2.2.1
# wcwidth                   0.2.13
# webcolors                 1.13
# webencodings              0.5.1
# websocket-client          1.8.0
# Werkzeug                  3.0.3
# wheel                     0.43.0
# widgetsnbextension        4.0.10
# wrapt                     1.16.0

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.16.1'

# %% [markdown]
# # DCGAN

# %%
import os
import numpy as np
import cv2 
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, LeakyReLU
from keras.layers import BatchNormalization, Conv2D, Conv2DTranspose
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import winsound

print("start")

plt.switch_backend('agg')

noise_dim = 100
w = 200
h = 200

class DCGAN(object):
    """ Deep Convolutional Generative Adversarial Network class """
    def __init__(self, width=w, height=h, channels=1):

        self.width = width
        self.height = height
        self.channels = channels

        self.shape = (self.width, self.height, self.channels)
        
        self.optimizer = Adam(lr=0.0002, beta_1=0.6, decay=8e-8)

        self.G = self.__generator()
        self.G.compile(loss='binary_crossentropy', optimizer=self.optimizer)

        self.D = self.__discriminator()
        self.D.compile(loss='binary_crossentropy', optimizer=self.optimizer, metrics=['accuracy'])

        self.stacked_generator_discriminator = self.__stacked_generator_discriminator()

        self.stacked_generator_discriminator.compile(loss='binary_crossentropy', optimizer=self.optimizer)


    def __generator(self):
        """ Declare generator """

        model = Sequential()

        model.add(Dense(128 * 25 * 25, activation="relu", input_dim=noise_dim))
        model.add(Reshape((25, 25, 128)))
        model.add(BatchNormalization(momentum=0.8))
        
        model.add(Conv2DTranspose(128, kernel_size=3, strides=2, padding="same", activation="relu"))
        model.add(BatchNormalization(momentum=0.8))
        
        model.add(Conv2DTranspose(64, kernel_size=3, strides=2, padding="same", activation="relu"))
        model.add(BatchNormalization(momentum=0.8))
        
        model.add(Conv2DTranspose(1, kernel_size=3, strides=1, padding="same", activation="tanh"))

        return model

    def __discriminator(self):
        """ Declare discriminator """

        model = Sequential()

        model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=self.shape, padding="same"))
        model.add(LeakyReLU(alpha=0.2))
        
        model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        
        model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        
        model.add(Flatten())
        model.add(Dense(1, activation='sigmoid'))

        return model
    
    def __stacked_generator_discriminator(self):
        self.D.trainable = False
        noise = Input(shape=(noise_dim,))
        img = self.G(noise)
        valid = self.D(img)
        #valid = self.D(img_flat)
        return Model(noise, valid)

    
    
    def train(self, X_train, epochs=2000, batch=32, save_interval=100):
        for cnt in range(epochs):

            # train discriminator
            random_index = np.random.randint(0, len(X_train) - np.int64(batch/2))
            legit_images = X_train[random_index : random_index + np.int64(batch/2)]

            gen_noise = np.random.normal(0, 1, (np.int64(batch/2), noise_dim))
            syntetic_images = self.G.predict(gen_noise)

            x_combined_batch = np.concatenate((legit_images, syntetic_images))
            y_combined_batch = np.concatenate((np.ones((np.int64(batch/2), 1)), np.zeros((np.int64(batch/2), 1))))

            d_loss = self.D.train_on_batch(x_combined_batch, y_combined_batch)

            # train generator
            noise = np.random.normal(0, 1, (batch, noise_dim))
            y_mislabled = np.ones((batch, 1))
            g_loss = self.stacked_generator_discriminator.train_on_batch(noise, y_mislabled)

            print ('epoch: %d, [Discriminator :: d_loss: %f], [ Generator :: loss: %f]' % (cnt, d_loss[0], g_loss))

            if cnt % save_interval == 0:
                self.plot_images(save2file=True, step=cnt)


    def plot_images(self, save2file=False, samples=16, step=0):
        if not os.path.exists("./images"):
            os.makedirs("./images")
        filename = "./images/DCGAN/dolphin_%d.png" % step
        noise = np.random.normal(0, 1, (samples, noise_dim))

        images = self.G.predict(noise)

        plt.figure(figsize=(w, h))

        for i in range(images.shape[0]):
            plt.subplot(4, 4, i+1)
            image = images[i, :, :, 0]
            plt.imshow(image, cmap='gray')
            plt.axis('off')
        plt.tight_layout()

        if save2file:
            plt.savefig(filename)
            plt.close('all')
            winsound.Beep(1000,1000)
        else:
            plt.show()
    

if __name__ == '__main__':
    image_folder_path = r'2022-3-8\gray\class'
    image_files = os.listdir(image_folder_path)
    X_train = []

    for image_file in image_files:
        image_path = os.path.join(image_folder_path, image_file)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        if image is not None and not image.size == 0:
            image = cv2.resize(image, (w, h))
            X_train.append(image)
        else:
            print(image_file)

    X_train = np.array(X_train) / 255.0
    X_train = np.expand_dims(X_train, axis=-1)

    dcgan = DCGAN()
    dcgan.train(X_train)
    
# 訓練完畢提示音    
winsound.Beep(2000,2000)
# Out:
# start
# WARNING:tensorflow:Model was constructed with shape (None, 200, 200, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 200, 200, 1), dtype=tf.float32, name='conv2d_15_input'), name='conv2d_15_input', description="created by layer 'conv2d_15_input'"), but it was called on an input with incompatible shape (None, 100, 100, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-db4e4bfb3cf4> in <module>
#     159     X_train = np.expand_dims(X_train, axis=-1)
#     160
# --> 161     dcgan = DCGAN()
#     162     dcgan.train(X_train)
#     163
#
# <ipython-input-7-db4e4bfb3cf4> in __init__(self, width, height, channels)
#      35         self.D.compile(loss='binary_crossentropy', optimizer=self.optimizer, metrics=['accuracy'])
#      36
# ---> 37         self.stacked_generator_discriminator = self.__stacked_generator_discriminator()
#      38
#      39         self.stacked_generator_discriminator.compile(loss='binary_crossentropy', optimizer=self.optimizer)
#
# <ipython-input-7-db4e4bfb3cf4> in __stacked_generator_discriminator(self)
#      84         noise = Input(shape=(noise_dim,))
#      85         img = self.G(noise)
# ---> 86         valid = self.D(img)
#      87         #valid = self.D(img_flat)
#      88         return Model(noise, valid)
#
# c:\users\tosha.e.t\appdata\local\programs\python\python39\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# c:\users\tosha.e.t\appdata\local\programs\python\python39\lib\site-packages\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     245           value = value.value
#     246         if value is not None and shape_as_list[int(axis)] not in {value, None}:
# --> 247           raise ValueError(
#     248               f'Input {input_index} of layer "{layer_name}" is '
#     249               f'incompatible with the layer: expected axis {axis}'
#
# ValueError: Exception encountered when calling layer "sequential_13" (type Sequential).
#
# Input 0 of layer "dense_11" is incompatible with the layer: expected axis -1of input shape to have value 80000, but received input with shape (None, 21632)
#
# Call arguments received:
#   • inputs=tf.Tensor(shape=(None, 100, 100, 1), dtype=float32)
#   • training=None
#   • mask=None

# %%
print("gsdgf")
# Out:
# gsdgf

# %% [markdown]
# # WGAN

# %%
import os
import numpy as np
import cv2 
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, PReLU
from keras.layers import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
from keras import backend as K
from tensorflow.keras.optimizers import Adam, RMSprop
import matplotlib.pyplot as plt
import winsound

plt.switch_backend('agg')

noise_dim = 200

class WGAN(object):
    """ Wasserstein Generative Adversarial Network class """
    def __init__(self, width=50, height=50, channels=1):

        self.width = width
        self.height = height
        self.channels = channels

        self.shape = (self.width, self.height, self.channels)
        
        self.optimizer = RMSprop(lr=0.00005)

        self.G = self.__generator()
        self.G.compile(loss=self.wasserstein_loss, optimizer=self.optimizer)  # 修正此處

        self.D = self.__discriminator()
        self.D.compile(loss=self.wasserstein_loss, optimizer=self.optimizer)  # 修正此處

        self.stacked_generator_discriminator = self.__stacked_generator_discriminator()

        self.stacked_generator_discriminator.compile(loss=self.wasserstein_loss, optimizer=self.optimizer)  # 修正此處
        
    
    def wasserstein_loss(self, y_true, y_pred):
        return K.mean(y_true * y_pred)


    def __generator(self):
        """ Declare generator """

        model = Sequential()
        model.add(Dense(256, input_shape=(200,))) #noise_dim
        model.add(PReLU()) #LeakyReLU(alpha=0.2)
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(512))
        model.add(PReLU())
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(1024))
        model.add(PReLU())
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(2048))
        model.add(PReLU())
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(4096))
        model.add(PReLU())
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(8192))
        model.add(PReLU())
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(self.width  * self.height * self.channels, activation='tanh'))
        model.add(Reshape((self.width, self.height, self.channels)))

        return model

    def __discriminator(self):
        """ Declare discriminator """

        model = Sequential()
        model.add(Flatten(input_shape=self.shape))
        model.add(Dense(8192))
        model.add(PReLU())
        model.add(Dense(4096))
        model.add(PReLU())
        model.add(Dense(2048))
        model.add(PReLU())
        model.add(Dense(1024))
        model.add(PReLU())
        model.add(Dense(512))
        model.add(PReLU())
        model.add(Dense(256))
        model.add(PReLU())
        
        # 使用線性激活函數而不是 sigmoid
        model.add(Dense(1, activation='linear'))
        
        model.summary()

        return model

    def __stacked_generator_discriminator(self):

        self.D.trainable = False

        model = Sequential()
        model.add(self.G)
        model.add(self.D)

        return model
    
    #epochs=20000
    def train(self, X_train, epochs=100002, batch=32, save_interval=100, clip_value=0.01):
        for cnt in range(epochs):

            # train discriminator
            random_index = np.random.randint(0, len(X_train) - np.int64(batch/2))
            legit_images = X_train[random_index : random_index + np.int64(batch/2)]

            gen_noise = np.random.normal(0, 1, (np.int64(batch/2), noise_dim))
            syntetic_images = self.G.predict(gen_noise)

            x_combined_batch = np.concatenate((legit_images, syntetic_images))
            y_combined_batch = np.concatenate((-np.ones((np.int64(batch/2), 1)), np.ones((np.int64(batch/2), 1))))

            d_loss = self.D.train_on_batch(x_combined_batch, y_combined_batch)
            # Clip discriminator weights
            for l in self.D.layers:
                weights = l.get_weights()
                weights = [np.clip(w, -clip_value, clip_value) for w in weights]
                l.set_weights(weights)

            # train generator
            noise = np.random.normal(0, 1, (batch, noise_dim))
            y_mislabled = -np.ones((batch, 1))
            g_loss = self.stacked_generator_discriminator.train_on_batch(noise, y_mislabled)

            print ('epoch: %d, [Discriminator :: d_loss: %f], [ Generator :: loss: %f]' % (cnt, -d_loss, -g_loss))

            if cnt % save_interval == 0:
                self.plot_images(save2file=True, step=cnt)


    def plot_images(self, save2file=False, samples=16, step=0):
        if not os.path.exists("./images"):
            os.makedirs("./images")
        filename = "./images/WGAN/Dolphin_%d.png" % step
        noise = np.random.normal(0, 1, (samples, noise_dim)) #noise_dim

        images = self.G.predict(noise)

        plt.figure(figsize=(50, 50))

        for i in range(images.shape[0]):
            plt.subplot(4, 4, i+1)
            image = images[i, :, :, 0]  # 取出灰階通道
            plt.imshow(image, cmap='gray')
            plt.axis('off')
        plt.tight_layout()

        if save2file:
            plt.savefig(filename)
            plt.close('all')
            winsound.Beep(1000,1000)
        else:
            plt.show()
    



if __name__ == '__main__':
    image_folder_path = r'C:\Users\Tosha.E.T\Documents\GitHub\DolphinSkull\2022-3-8\gray\class' #r'C:\Users\Tosha.E.T\Documents\GitHub\DolphinSkull\number\gray\class_1'#
    image_files = os.listdir(image_folder_path)
    X_train = []

    for image_file in image_files:
        image_path = os.path.join(image_folder_path, image_file)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        if image is not None and not image.size == 0:
            # 如果圖片成功讀取，並且尺寸不為空，則進行調整大小
            image = cv2.resize(image, (50, 50))
            X_train.append(image)
            #print(image)
        else:
            print(image_file)

    X_train = np.array(X_train) / 255.0
    X_train = np.expand_dims(X_train, axis=-1)

    wgan = WGAN()
    wgan.train(X_train)
    

    
# 訓練完畢提示音    
winsound.Beep(2000,2000)
# Out:
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_13 (Flatten)        (None, 2500)              0
#
#  dense_189 (Dense)           (None, 8192)              20488192
#
#  p_re_lu_162 (PReLU)         (None, 8192)              8192
#
#  dense_190 (Dense)           (None, 4096)              33558528
#
#  p_re_lu_163 (PReLU)         (None, 4096)              4096
#
#  dense_191 (Dense)           (None, 2048)              8390656
#
#  p_re_lu_164 (PReLU)         (None, 2048)              2048
#
#  dense_192 (Dense)           (None, 1024)              2098176
#
#  p_re_lu_165 (PReLU)         (None, 1024)              1024
#
#  dense_193 (Dense)           (None, 512)               524800
#
#  p_re_lu_166 (PReLU)         (None, 512)               512
#
#  dense_194 (Dense)           (None, 256)               131328
#
#  p_re_lu_167 (PReLU)         (None, 256)               256
#
#  dense_195 (Dense)           (None, 1)                 257
#
# =================================================================
# Total params: 65,208,065
# Trainable params: 65,208,065
# Non-trainable params: 0
# _________________________________________________________________
# epoch: 0, [Discriminator :: d_loss: -0.024802], [ Generator :: loss: 0.000063]
# epoch: 1, [Discriminator :: d_loss: 0.000097], [ Generator :: loss: 0.000074]
# epoch: 2, [Discriminator :: d_loss: 0.000157], [ Generator :: loss: 0.000033]
# epoch: 3, [Discriminator :: d_loss: 0.000212], [ Generator :: loss: -0.000003]
# epoch: 4, [Discriminator :: d_loss: 0.000303], [ Generator :: loss: -0.000046]
# epoch: 5, [Discriminator :: d_loss: 0.000472], [ Generator :: loss: -0.000125]
# epoch: 6, [Discriminator :: d_loss: 0.000647], [ Generator :: loss: -0.000270]
# epoch: 7, [Discriminator :: d_loss: 0.000875], [ Generator :: loss: -0.000536]
# epoch: 8, [Discriminator :: d_loss: 0.001134], [ Generator :: loss: -0.000812]
# epoch: 9, [Discriminator :: d_loss: 0.001510], [ Generator :: loss: -0.001532]
# epoch: 10, [Discriminator :: d_loss: 0.001989], [ Generator :: loss: -0.002246]
# epoch: 11, [Discriminator :: d_loss: 0.002496], [ Generator :: loss: -0.003710]
# epoch: 12, [Discriminator :: d_loss: 0.003306], [ Generator :: loss: -0.005247]
# epoch: 13, [Discriminator :: d_loss: 0.004131], [ Generator :: loss: -0.007677]
# epoch: 14, [Discriminator :: d_loss: 0.005301], [ Generator :: loss: -0.009905]
# epoch: 15, [Discriminator :: d_loss: 0.007105], [ Generator :: loss: -0.014854]
# epoch: 16, [Discriminator :: d_loss: 0.008704], [ Generator :: loss: -0.018413]
# epoch: 17, [Discriminator :: d_loss: 0.011380], [ Generator :: loss: -0.026901]
# epoch: 18, [Discriminator :: d_loss: 0.014791], [ Generator :: loss: -0.033233]
# epoch: 19, [Discriminator :: d_loss: 0.019379], [ Generator :: loss: -0.047391]
# epoch: 20, [Discriminator :: d_loss: 0.024942], [ Generator :: loss: -0.057973]
# epoch: 21, [Discriminator :: d_loss: 0.032427], [ Generator :: loss: -0.081753]
# epoch: 22, [Discriminator :: d_loss: 0.041422], [ Generator :: loss: -0.100258]
# epoch: 23, [Discriminator :: d_loss: 0.055936], [ Generator :: loss: -0.137213]
# epoch: 24, [Discriminator :: d_loss: 0.069700], [ Generator :: loss: -0.165900]
